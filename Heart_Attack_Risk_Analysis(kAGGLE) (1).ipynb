# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
sample_sub = pd.read_csv("/content/sample_submission (6).csv")
sample_sub
# Out:
#      Patient ID  Heart Attack Risk
# 0       BMW7812                  0
# 1       XXM0972                  0
# 2       RQX1211                  0
# 3       RVN4963                  0
# 4       NCU1956                  0
# ...         ...                ...
# 1748    GQZ5013                  0
# 1749    FDK8693                  0
# 1750    SVO4635                  0
# 1751    KQR8949                  0
# 1752    XKA5925                  0
#
# [1753 rows x 2 columns]

# %%
df_test = pd.read_csv("/content/test (2).csv")

df_test
# Out:
#      Patient ID  Age     Sex  Cholesterol Blood Pressure  Heart Rate  \
# 0       BMW7812   67    Male          208         158/88          72
# 1       XXM0972   84    Male          220         131/68         107
# 2       RQX1211   60    Male          145         160/98          71
# 3       RVN4963   45    Male          294         130/84          66
# 4       NCU1956   36    Male          133         161/90          97
# ...         ...  ...     ...          ...            ...         ...
# 1748    GQZ5013   81    Male          137         143/64          61
# 1749    FDK8693   34  Female          304         102/92          93
# 1750    SVO4635   75    Male          176         102/89          78
# 1751    KQR8949   25    Male          307         137/94          78
# 1752    XKA5925   47    Male          250         161/75         105
#
#       Diabetes  Family History  Smoking  Obesity  ...  Stress Level  \
# 0            0               0        1        0  ...             9
# ...

# %%
df_train = pd.read_csv("/content/train.csv")

df_train
# Out:
#      Patient ID  Age     Sex  Cholesterol Blood Pressure  Heart Rate  \
# 0       RDG0550   33    Male          200         129/90          48
# 1       NMA3851   56  Female          262        159/105          46
# 2       TUI5807   19  Female          140        161/109          54
# 3       YYT5016   50  Female          163         120/62          53
# 4       ZAC5937   89  Female          144        153/110          92
# ...         ...  ...     ...          ...            ...         ...
# 7005    BCB2291   29  Female          267        104/105          87
# 7006    KIG5207   83    Male          296         134/99          77
# 7007    GCY1316   54    Male          120         134/84         103
# 7008    RPK2629   42  Female          147         144/76          81
# 7009    CWO3455   61    Male          176         172/60          56
#
#       Diabetes  Family History  Smoking  Obesity  ...  \
# 0            0               1        1        1  ...
# ...

# %% [markdown]
# **Data Preprocessing**

# %%
df_test.describe()
# Out:
#                Age  Cholesterol   Heart Rate     Diabetes  Family History  \
# count  1753.000000  1753.000000  1753.000000  1753.000000     1753.000000
# mean     54.498003   259.863092    74.684541     0.650314        0.497433
# std      21.070471    81.499465    20.727584     0.477007        0.500136
# min      18.000000   120.000000    40.000000     0.000000        0.000000
# 25%      36.000000   192.000000    56.000000     0.000000        0.000000
# 50%      54.000000   258.000000    75.000000     1.000000        0.000000
# 75%      73.000000   332.000000    92.000000     1.000000        1.000000
# max      90.000000   400.000000   110.000000     1.000000        1.000000
#
#            Smoking      Obesity  Alcohol Consumption  Exercise Hours Per Week  \
# count  1753.000000  1753.000000          1753.000000              1753.000000
# mean      0.899030     0.507701             0.606959                10.154940
# ...

# %%
df_train.describe()
# Out:
#                Age  Cholesterol   Heart Rate     Diabetes  Family History  \
# count  7010.000000  7010.000000  7010.000000  7010.000000     7010.000000
# mean     53.510414   259.880742    75.105991     0.652782        0.491869
# std      21.290957    80.709248    20.507160     0.476120        0.499970
# min      18.000000   120.000000    40.000000     0.000000        0.000000
# 25%      35.000000   192.000000    57.000000     0.000000        0.000000
# 50%      53.000000   259.000000    75.000000     1.000000        0.000000
# 75%      72.000000   329.000000    93.000000     1.000000        1.000000
# max      90.000000   400.000000   110.000000     1.000000        1.000000
#
#            Smoking      Obesity  Alcohol Consumption  Exercise Hours Per Week  \
# count  7010.000000  7010.000000          7010.000000              7010.000000
# mean      0.896291     0.499857             0.595863                 9.979109
# ...

# %%
df_test.columns
# Out:
# Index(['Patient ID', 'Age', 'Sex', 'Cholesterol', 'Blood Pressure',
#        'Heart Rate', 'Diabetes', 'Family History', 'Smoking', 'Obesity',
#        'Alcohol Consumption', 'Exercise Hours Per Week', 'Diet',
#        'Previous Heart Problems', 'Medication Use', 'Stress Level',
#        'Sedentary Hours Per Day', 'Income', 'BMI', 'Triglycerides',
#        'Physical Activity Days Per Week', 'Sleep Hours Per Day', 'Country',
#        'Continent', 'Hemisphere'],
#       dtype='object')

# %%
df_train.columns
# Out:
# Index(['Patient ID', 'Age', 'Sex', 'Cholesterol', 'Blood Pressure',
#        'Heart Rate', 'Diabetes', 'Family History', 'Smoking', 'Obesity',
#        'Alcohol Consumption', 'Exercise Hours Per Week', 'Diet',
#        'Previous Heart Problems', 'Medication Use', 'Stress Level',
#        'Sedentary Hours Per Day', 'Income', 'BMI', 'Triglycerides',
#        'Physical Activity Days Per Week', 'Sleep Hours Per Day', 'Country',
#        'Continent', 'Hemisphere', 'Heart Attack Risk'],
#       dtype='object')

# %%
df_train.shape
# Out:
# (7010, 26)

# %%
df_test.shape
# Out:
# (1753, 25)

# %% [markdown]
# **Null Value Handling**

# %%
df_test.isnull().sum()
# Out:
# Patient ID                         0
# Age                                0
# Sex                                0
# Cholesterol                        0
# Blood Pressure                     0
# Heart Rate                         0
# Diabetes                           0
# Family History                     0
# Smoking                            0
# Obesity                            0
# Alcohol Consumption                0
# Exercise Hours Per Week            0
# Diet                               0
# Previous Heart Problems            0
# Medication Use                     0
# Stress Level                       0
# Sedentary Hours Per Day            0
# Income                             0
# BMI                                0
# Triglycerides                      0
# Physical Activity Days Per Week    0
# Sleep Hours Per Day                0
# Country                            0
# Continent                          0
# Hemisphere                         0
# dtype: int64

# %%
df_train.isnull().sum()
# Out:
# Patient ID                         0
# Age                                0
# Sex                                0
# Cholesterol                        0
# Blood Pressure                     0
# Heart Rate                         0
# Diabetes                           0
# Family History                     0
# Smoking                            0
# Obesity                            0
# Alcohol Consumption                0
# Exercise Hours Per Week            0
# Diet                               0
# Previous Heart Problems            0
# Medication Use                     0
# Stress Level                       0
# Sedentary Hours Per Day            0
# Income                             0
# BMI                                0
# Triglycerides                      0
# Physical Activity Days Per Week    0
# Sleep Hours Per Day                0
# Country                            0
# Continent                          0
# Hemisphere                         0
# ...

# %%
  df_test = df_test.drop(['Patient ID', 'Blood Pressure'], axis=1)

  columns_to_standardize = ['Age', 'Cholesterol', 'Heart Rate', 'Exercise Hours Per Week',
                              'Stress Level', 'Sedentary Hours Per Day', 'Income', 'BMI',
                              'Triglycerides', 'Physical Activity Days Per Week', 'Sleep Hours Per Day']
  scaler = StandardScaler()
  df_test[columns_to_standardize] = scaler.fit_transform(df_test[columns_to_standardize])

  columns_to_encode = ['Sex', 'Diet', 'Country', 'Continent', 'Hemisphere']
  df_test = pd.get_dummies(df_test, columns=columns_to_encode, drop_first=True)

# %%
df_train = df_train.drop(['Patient ID', 'Blood Pressure'], axis=1)

columns_to_standardize = ['Age', 'Cholesterol', 'Heart Rate', 'Exercise Hours Per Week',
                              'Stress Level', 'Sedentary Hours Per Day', 'Income', 'BMI',
                              'Triglycerides', 'Physical Activity Days Per Week', 'Sleep Hours Per Day']
scaler = StandardScaler()
df_train[columns_to_standardize] = scaler.fit_transform(df_train[columns_to_standardize])

columns_to_encode = ['Sex', 'Diet', 'Country', 'Continent', 'Hemisphere']
df_train = pd.get_dummies(df_train, columns=columns_to_encode, drop_first=True)

# %%
train_df, val_df = train_test_split(df_train, test_size=0.2)

# %%
X_train = train_df.drop(['Heart Attack Risk'], axis=1)
y_train = train_df['Heart Attack Risk']

X_val = val_df.drop(['Heart Attack Risk'], axis=1)
y_val = val_df['Heart Attack Risk']

# %%
#import
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier

# %%
random = RandomForestClassifier(ccp_alpha=0.001, random_state=1, criterion='gini')
random.fit(X_train, y_train)
y_pred = random.predict(X_val)

y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
accuracy = accuracy_score(y_val, y_pred)
accuracy
# Out:
# 0.6583452211126961

# %%
y_pred = random.predict(df_test)

y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
sample_sub['Heart Attack Risk'] = y_pred
sample_sub.head()
# Out:
#   Patient ID  Heart Attack Risk
# 0    BMW7812                  0
# 1    XXM0972                  0
# 2    RQX1211                  0
# 3    RVN4963                  0
# 4    NCU1956                  0

# %%
sample_sub.to_csv('submission.csv', index=False)

# %% [markdown]
# **Encoding**
